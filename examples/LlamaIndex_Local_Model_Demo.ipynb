# %% [markdown]
# # LlamaIndex - Private Setup
#
# Using GPT4ALL and our HuggingFace embeddings, we will injest [Chapter 3 of the recent IPCC Climate Report](https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-3/), which covers oceans and coastal ecosystems. Using llama-index, this PDF is injested and vectorized, and questions can be answered about anything from this 172 paged report.
#
# Climate reports are long and tedious to read, so this demo will also help give some insight to the latest findings from the IPCC!
#
# Inspired by the recent popularity of [PrivateGPT](https://github.com/imartinez/privateGPT), this notebook will walk you through a llama-index setup that uses entirely local models. In this notebook, we use GPT4ALL and huggingface embeddings, which should run decently well on CPU alone. If you had more resources, we also provide some links further down for setting up any LLM from huggingface and running on GPU.

# %% [markdown]
# ## Dependencies Setup

# %% [markdown]
# ### Setup Line Wrapping

# %%
from IPython.display import HTML, display

def set_css():
  display(HTML('''
  <style>
    pre {
        white-space: pre-wrap;
    }
  </style>
  '''))
get_ipython().events.register('pre_run_cell', set_css)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %% [markdown]
# ### Download gpt4all model

# %%
# !wget https://gpt4all.io/models/ggml-gpt4all-j-v1.3-groovy.bin

# %% [markdown]
# ### Download 2023 IPPC Climate Report - Chapter 3 on Oceans and Coastal Ecosystems (172 Pages)

# %%
# !wget https://www.ipcc.ch/report/ar6/wg2/downloads/report/IPCC_AR6_WGII_Chapter03.pdf

# %% [markdown]
# ### Download extra packages

# %%
# !pip install pymupdf pygpt4all sentence_transformers accelerate
# Out:
# Requirement already satisfied: pymupdf in c:\users\chha\.conda\envs\llamaindex\lib\site-packages (1.22.3)
# Requirement already satisfied: pygpt4all in c:\users\chha\.conda\envs\llamaindex\lib\site-packages (1.1.0)
# Requirement already satisfied: sentence_transformers in c:\users\chha\.conda\envs\llamaindex\lib\site-packages (2.2.2)
# Requirement already satisfied: accelerate in c:\users\chha\.conda\envs\llamaindex\lib\site-packages (0.19.0)
# Requirement already satisfied: pygptj in c:\users\chha\.conda\envs\llamaindex\lib\site-packages (from pygpt4all) (2.0.3)
# Requirement already satisfied: pyllamacpp in c:\users\chha\.conda\envs\llamaindex\lib\site-packages (from pygpt4all) (2.3.0)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in c:\users\chha\.conda\envs\llamaindex\lib\site-packages (from sentence_transformers) (4.29.2)
# Requirement already satisfied: sentencepiece in c:\users\chha\.conda\envs\llamaindex\lib\site-packages (from sentence_transformers) (0.1.99)
# Requirement already satisfied: numpy in c:\users\chha\.conda\envs\llamaindex\lib\site-packages (from sentence_transformers) (1.24.1)
# Requirement already satisfied: huggingface-hub>=0.4.0 in c:\users\chha\.conda\envs\llamaindex\lib\site-packages (from sentence_transformers) (0.14.1)
# Requirement already satisfied: nltk in c:\users\chha\.conda\envs\llamaindex\lib\site-packages (from sentence_transformers) (3.8.1)
# Requirement already satisfied: scikit-learn in c:\users\chha\.conda\envs\llamaindex\lib\site-packages (from sentence_transformers) (1.2.2)
# Requirement already satisfied: torchvision in c:\users\chha\.conda\envs\llamaindex\lib\site-packages (from sentence_transformers) (0.15.2+cu117)
# Requirement already satisfied: tqdm in c:\users\chha\.conda\envs\llamaindex\lib\site-packages (from sentence_transformers) (4.65.0)
# Requirement already satisfied: torch>=1.6.0 in c:\users\chha\.conda\envs\llamaindex\lib\site-packages (from sentence_transformers) (2.0.1+cu117)
# Requirement already satisfied: scipy in c:\users\chha\.conda\envs\llamaindex\lib\site-packages (from sentence_transformers) (1.10.1)
# Requirement already satisfied: pyyaml in c:\users\chha\.conda\envs\llamaindex\lib\site-packages (from accelerate) (6.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\chha\.conda\envs\llamaindex\lib\site-packages (from accelerate) (23.1)
# Requirement already satisfied: psutil in c:\users\chha\.conda\envs\llamaindex\lib\site-packages (from accelerate) (5.9.0)
# Requirement already satisfied: requests in c:\users\chha\.conda\envs\llamaindex\lib\site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2.28.1)
# Requirement already satisfied: filelock in c:\users\chha\.conda\envs\llamaindex\lib\site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (3.12.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\chha\.conda\envs\llamaindex\lib\site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (4.5.0)
# Requirement already satisfied: fsspec in c:\users\chha\.conda\envs\llamaindex\lib\site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2023.5.0)
# Requirement already satisfied: networkx in c:\users\chha\.conda\envs\llamaindex\lib\site-packages (from torch>=1.6.0->sentence_transformers) (3.0)
# Requirement already satisfied: jinja2 in c:\users\chha\.conda\envs\llamaindex\lib\site-packages (from torch>=1.6.0->sentence_transformers) (3.1.2)
# Requirement already satisfied: sympy in c:\users\chha\.conda\envs\llamaindex\lib\site-packages (from torch>=1.6.0->sentence_transformers) (1.11.1)
# Requirement already satisfied: colorama in c:\users\chha\.conda\envs\llamaindex\lib\site-packages (from tqdm->sentence_transformers) (0.4.6)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\chha\.conda\envs\llamaindex\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (0.13.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\chha\.conda\envs\llamaindex\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2023.5.5)
# Requirement already satisfied: joblib in c:\users\chha\.conda\envs\llamaindex\lib\site-packages (from nltk->sentence_transformers) (1.2.0)
# Requirement already satisfied: click in c:\users\chha\.conda\envs\llamaindex\lib\site-packages (from nltk->sentence_transformers) (8.1.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\chha\.conda\envs\llamaindex\lib\site-packages (from scikit-learn->sentence_transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\chha\.conda\envs\llamaindex\lib\site-packages (from torchvision->sentence_transformers) (9.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\chha\.conda\envs\llamaindex\lib\site-packages (from jinja2->torch>=1.6.0->sentence_transformers) (2.1.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\chha\.conda\envs\llamaindex\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\chha\.conda\envs\llamaindex\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (1.26.13)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\chha\.conda\envs\llamaindex\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\chha\.conda\envs\llamaindex\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\chha\.conda\envs\llamaindex\lib\site-packages (from sympy->torch>=1.6.0->sentence_transformers) (1.2.1)
# WARNING: Ignoring invalid distribution -ymupdf (c:\users\chha\.conda\envs\llamaindex\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymupdf (c:\users\chha\.conda\envs\llamaindex\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymupdf (c:\users\chha\.conda\envs\llamaindex\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymupdf (c:\users\chha\.conda\envs\llamaindex\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymupdf (c:\users\chha\.conda\envs\llamaindex\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymupdf (c:\users\chha\.conda\envs\llamaindex\lib\site-packages)

# %% [markdown]
# ### Install LLaMa from source folder

# %%
# !pip install -q -U ../
# Out:
# WARNING: Ignoring invalid distribution -ymupdf (c:\users\chha\.conda\envs\llamaindex\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymupdf (c:\users\chha\.conda\envs\llamaindex\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymupdf (c:\users\chha\.conda\envs\llamaindex\lib\site-packages)
#     WARNING: Ignoring invalid distribution -ymupdf (c:\users\chha\.conda\envs\llamaindex\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymupdf (c:\users\chha\.conda\envs\llamaindex\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymupdf (c:\users\chha\.conda\envs\llamaindex\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymupdf (c:\users\chha\.conda\envs\llamaindex\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymupdf (c:\users\chha\.conda\envs\llamaindex\lib\site-packages)

# %% [markdown]
# ## Documents setup
#
# Here, we use PyMuPDFReader to quickly load all 172 pages of the climate report PDF. The `metadata=True` option will automatically set some helpful information like page numbers and filename, to help us keep track of sources.

# %%
from langchain.embeddings.huggingface import HuggingFaceEmbeddings
from langchain.llms import GPT4All
from llama_index.node_parser.simple import SimpleNodeParser
from llama_index.langchain_helpers.text_splitter import TokenTextSplitter
from llama_index import (
    GPTVectorStoreIndex, 
    LangchainEmbedding, 
    LLMPredictor, 
    ServiceContext, 
    StorageContext, 
    download_loader,
    PromptHelper
)

# %%
PyMuPDFReader = download_loader("PyMuPDFReader")

# %%
documents = PyMuPDFReader().load(file_path='../content/Efficient Methods for NLP.pdf', metadata=True)
# documents = PyMuPDFReader().load(file_path='/content/What_We_Know_GenZ.pdf', metadata=True)
# ensure document texts are not bytes objects
for doc in documents:
    doc.text = doc.text.decode()

# %%
# print a document to test. Each document is a single page from the pdf, with appropriate metadata
documents[10]
# Out:
# Document(text='cally comes with a number of caveats. First, sam-\npling frequency is often restricted at various levels\nof the stack and may result in a lag in measure-\nment start. Consequently, shorter experiments may\nlog an energy use of zero, and there will almost\nalways be energy demand that is missed. Second,\ninefﬁciencies such as heat loss are not reported by\ncurrent APIs and hence, do not cover cooling and\nother system management activities. Third, not all\narchitectures and operating systems are supported.\nFor instance, power consumption under macOS\nis difﬁcult to manage, and direct ﬁgures for TPU\npower consumption are not available.\nCarbon emissions\nCarbon emissions are usually\ncomputed using the power consumption and the\ncarbon intensity of the marginal energy genera-\ntion used to run the program. Thus, low-energy\ndoes not mean low-carbon, and high-energy models\ncan—in the right region and with some care—be\nzero-carbon in terms of point energy consumption\nimpact, if executed at the right time (i.e., when the\nenergy mix is low-carbon intensity, Dodge et al.,\n2022). For estimating the CO2 emissions from a\nspeciﬁc program execution, APIs such as Electric-\nityMap2 provide real-time access to carbon inten-\nsity for many regions. However, as carbon inten-\nsity varies and is affected by other factors like the\npower usage efﬁciency in a data center, it is often a\npoor basis for comparison; in fact, Henderson et al.\n(2020) recommended using multiple runs for a sta-\nble estimate. Furthermore, one needs to consider\nthat zero-carbon program executions still consume\nenergy, and that efﬁciency does not intrinsically\nguarantee a reduction in overall resource consump-\ntion, as the resulting cost reduction may lead to\nan increase in demand counteracting any gains, an\neffect known as Jevons’ paradox (Jevons, 1866).\n8.2\nOpen Challenges in Measuring Efﬁciency\nHardware choice can lead to pronounced differ-\nences in certain efﬁciency measurements such as\nlatency and thoroughput (Lee-Thorp et al., 2022).\nProperly measuring efﬁciency remains a major\nchallenge (Cao et al., 2020).\nSeparating different stages\nIt is important to\ncharacterize efﬁciency of pre-training and ﬁne-\ntuning stages separately (Secs. 4 and 5). Models\nmay present different memory requirements during\ntraining yet result in trained models with compa-\n2https://electricitymap.org\nrable inference memory consumption. This is be-\ncause training often involves design choices that\nincrease the memory overhead of backward propa-\ngation. Further, some optimizers may require sub-\nstantially more memory than others. Similarly, pa-\nrameter sharing techniques may show little beneﬁts\nduring training but show memory improvements at\ninference (Dehghani et al., 2022). Finally, while\nlarger models run slower than smaller ones, they\nconverge faster and better compress using methods\nlike pruning and quantization (Li et al., 2020c).\nDisagreement between cost factors\nAs par-\ntially discussed in Sec. 7.2, cost indicators may\ndisagree with each other. For instance, mixture of\nexperts increases the overall parameter count, but\nimproves the trade-off between quality and FLOPs,\nas they minimize the per-data cost by routing to\nsubsections of the model (Rajbhandari et al., 2022).\nConversely, unstructured sparsity techniques can\nsigniﬁcantly minimize the overall number of\nFLOPs, yet in practice, it introduces low-level\noperations that can lead to far higher memory\nrequirements to store the indices that indicate\nwhat part of the matrix is sparse (Qu et al., 2022).\nFinally, Chen et al. (2022) and Dao et al. (2022a)\nfound speciﬁc sparsity patterns that achieve more\npredictable speedups with current hardware.\nTrade-offs with other desiderata\nOne major,\nbut seldom studied concern when improving ef-\nﬁciency are trade-offs with other desiderata such\nas fairness and robustness. For instance, Hooker\net al. (2020), Renduchintala et ...

# %% [markdown]
# Note that due to model limitations (and considerations for speed), these settings are non-standard, but should help ensure reasonable resource usage with GPT4ALL

# %% [markdown]
# ## GPU Llama Index
#
# As stated earlier, if you have a modest GPU available (at least 15GB of VRAM), you can speed things up considerably.
#
# This next section will setup a new predictor from Huggingface, using the Writer/camel-5b-hf model (which is also conviently licensed for commericial use).
#
# (If you are running in colab, switch to a GPU instance first!)

# %% [markdown]
# ### LLM + Embed Model Setup

# %%
# setup prompts - specific to Camel
from llama_index.prompts.prompts import SimpleInputPrompt

# This will wrap the default prompts that are internal to llama-index
# taken from https://huggingface.co/Writer/camel-5b-hf
query_wrapper_prompt = SimpleInputPrompt(
    "A continuación hay una instrucción que describe una tarea. "
    "Escribe una respuesta que complete adecuadamente la solicitud.\n\n"
    "### Instruction:\n{query_str}\n\n### Response:"
)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
import torch
from llama_index.llm_predictor import HuggingFaceLLMPredictor

# NOTE: the first run of this will download/cache the weights, ~20GB
hf_predictor = HuggingFaceLLMPredictor(
    max_input_size=2048, 
    max_new_tokens=256,
    temperature=0.25,
    do_sample=False,
    query_wrapper_prompt=query_wrapper_prompt,
    tokenizer_name="Writer/camel-5b-hf",
    model_name="Writer/camel-5b-hf",
    device_map="auto",
    tokenizer_kwargs={"max_length": 2048},
    model_kwargs={"torch_dtype": torch.bfloat16, "cache_dir": "../cache"},
    
)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Downloading shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading (…)l-00001-of-00003.bin:   0%|          | 0.00/10.0G [00:00<?, ?B/s]
# Downloading (…)l-00002-of-00003.bin:   0%|          | 0.00/9.99G [00:00<?, ?B/s]
# Downloading (…)l-00003-of-00003.bin:   0%|          | 0.00/1.09G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
embed_model = LangchainEmbedding(HuggingFaceEmbeddings(model_name="sentence-transformers/all-mpnet-base-v2"))
service_context = ServiceContext.from_defaults(chunk_size_limit=512, llm_predictor=hf_predictor, embed_model=embed_model)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %% [markdown]
# ### Construct index using GPU
#
# Since we are using a GPU now, the emebddings are much faster to generate! Plus, now we are working with larger chunks, which enables the embeddings to represent the text and enable better retrieval.

# %%
index = GPTVectorStoreIndex.from_documents(documents, service_context=service_context)
index.storage_context.persist(persist_dir="../storage")
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %% [markdown]
# #### (Optional) Load if already saved

# %%
from llama_index import load_index_from_storage
storage_context = StorageContext.from_defaults(persist_dir="../storage")
index = load_index_from_storage(storage_context, service_context=service_context)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %% [markdown]
# ### Query using GPU
#
# With a GPU, the response will begin streaming very quickly. Camel is an excellent model given it's modest size of 5B parameters!

# %%
query_engine = index.as_query_engine(streaming=True, similarity_top_k=3, service_context=service_context)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
response_stream = query_engine.query("What are the stages of NLP process?")
response_stream.print_response_stream()
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Token indices sequence length is longer than the specified maximum sequence length for this model (1305 > 512). Running this sequence through the model will result in indexing errors
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# c:\Users\chha\.conda\envs\llamaindex\lib\site-packages\transformers\generation\utils.py:1445: UserWarning: You are calling .generate() with the `input_ids` being on a device type different than your model's device. `input_ids` is on cuda, whereas the model is on cpu. You may experience unexpected behaviors or slower generation. Please make sure that you have put `input_ids` to the correct device by calling for example input_ids = input_ids.to('cpu') before running `.generate()`.
#   warnings.warn(

# %% [markdown]
# Compared to GPT4ALL, this response is more complete and accurate. You can inspect the source nodes below:

# %%
print(response_stream.source_nodes)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# [NodeWithScore(node=Node(text='Tapo, Nishant Sub-\nramani, Artem Sokolov, Claytone Sikasote,\nMonang Setyawan, Supheakmungkol Sarin,\nSokhar Samb, Benoît Sagot, Clara Rivera,\nAnnette Rios, Isabel Papadimitriou, Salomey\nOsei, Pedro Ortiz Suarez, Iroro Orife, Kelechi\nOgueji, Andre Niyongabo Rubungo, Toan Q.\nNguyen, Mathias Müller, André Müller, Sham-\nsuddeen Hassan Muhammad, Nanda Muham-\nmad, Ayanda Mnyakeni, Jamshidbek Mirza-\nkhalov, Tapiwanashe Matangira, Colin Leong,\nNze Lawson, Sneha Kudugunta, Yacine Jer-\nnite, Mathias Jenny, Orhan Firat, Bonaven-\nture F. P. Dossou, Sakhile Dlamini, Nisansa\nde Silva, Sakine Çabuk Ballı, Stella Biderman,\nAlessia Battisti, Ahmed Baruwa, Ankur Bapna,\nPallavi Baljekar, Israel Abebe Azime, Ayodele\nAwokoya, Duygu Ataman, Orevaoghene Ahia,\nOghenefego Ahia, Sweta Agrawal, and Mofe-\ntoluwa Adeyemi. 2022. Quality at a Glance:\nAn Audit of Web-Crawled Multilingual Datasets.\nTransactions of the Association for Computa-\ntional Linguistics, 10:50–72.\nM. Kumar, Benjamin Packer, and Daphne Koller.\n2010. Self-Paced Learning for Latent Variable\nModels. In Advances in Neural Information Pro-\ncessing Systems, volume 23. Curran Associates,\nInc.\nAndrey Kuzmin,\nMart Van', doc_id='04ee81db-f2ef-4703-9f07-c11fcac7ab44', embedding=None, doc_hash='b3ccaab34c46b148cf47c024b7bee6651c55816272570db0c1f602bea683928a', extra_info={'total_pages': 33, 'file_path': '../content/Efficient Methods for NLP.pdf', 'source': '22'}, node_info={'start': 863, 'end': 2030}, relationships={<DocumentRelationship.SOURCE: '1'>: '3b98b81b-4241-4419-b57c-6f02965ca454', <DocumentRelationship.PREVIOUS: '2'>: '67ea123f-4d58-4622-932e-9690a78e8ce6', <DocumentRelationship.NEXT: '3'>: 'c789b318-ef18-4237-b2fa-c0d39edef519'}), score=0.44631543499257476), NodeWithScore(node=Node(text='Radford, Jeffrey Wu, Rewon Child, David\nLuan, Dario Amodei, and Ilya Sutskever. 2019.\nLanguage Models are Unsupervised Multitask\nLearners. OpenAI blog, 1(8):9.\nJack W. Rae, Sebastian Borgeaud, Trevor Cai,\nKatie Millican, Jordan Hoffmann, H. Fran-\ncis Song, John Aslanides, Sarah Henderson,\nRoman Ring, Susannah Young, Eliza Ruther-\nford, Tom Hennigan, Jacob Menick, Albin Cas-\nsirer, Richard Powell, George van den Driess-\nche, Lisa Anne Hendricks, Maribeth Rauh, Po-\nSen Huang, Amelia Glaese, Johannes Welbl,\nSumanth Dathathri, Saffron Huang, Jonathan\nUesato, John Mellor, Irina Higgins, Antonia\nCreswell, Nat McAleese, Amy Wu, Erich Elsen,\nSiddhant M. Jayakumar, Elena Buchatskaya,\nDavid Budden, Esme Sutherland, Karen Si-\nmonyan, Michela Paganini, Laurent Sifre, Lena\nMartens, Xiang Lorraine Li, Adhiguna Kun-\ncoro, Aida Nematzadeh, Elena Gribovskaya,\nDomenic Donato, Angeliki Lazaridou, Arthur\nMensch, Jean-Baptiste Lespiau, Maria Tsim-\npoukelli, Nikolai Grigorev, Doug Fritz, Thibault\nSottiaux, Mantas Pajarskas, Toby Pohlen, Zhi-\ntao Gong, Daniel Toyama, Cyprien de Mas-\nson d’Autume, Yujia Li, Tayfun Terzi, Vladimir\nMikulik, Igor Babuschkin, Aidan Clark, Diego\nde Las Casas, Aurelia Guy, Chris Jones,', doc_id='a3e47f53-8bd8-46bc-a85c-bc46149a7bf2', embedding=None, doc_hash='2a7748afb9895ecd6f7f8e6fb119c54045d88b3d0ca28bb56905ffa4e5295951', extra_info={'total_pages': 33, 'file_path': '../content/Efficient Methods for NLP.pdf', 'source': '27'}, node_info={'start': 947, 'end': 2155}, relationships={<DocumentRelationship.SOURCE: '1'>: '91a749f4-3f85-4892-abd0-4b5c712ce816', <DocumentRelationship.PREVIOUS: '2'>: 'ea10cefe-9954-4bfd-b9cd-ca2c9cda3edc', <DocumentRelationship.NEXT: '3'>: 'e720c3e1-287e-40df-9698-93194a217372'}), score=0.43172039993705974), NodeWithScore(node=Node(text='LeCun, John Denker, and Sara Solla. 1989.\nOptimal Brain Damage. In Advances in Neu-\nral Information Processing Systems, volume 2.\nMorgan-Kaufmann.\nJi-Ung Lee,\nJan-Christoph Klie,\nand Iryna\nGurevych. 2022a. Annotation Curricula to Im-\nplicitly Train Non-Expert Annotators. Computa-\ntional Linguistics, 48(2):343–373.\nJi-Ung Lee, Christian M. Meyer,  ...
